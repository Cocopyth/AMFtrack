# %%
from amftrack.pipeline.launching.run_super import (
    run_launcher,
    directory_scratch,
    directory_project,
    directory_project,
    run_parallel_stitch,
)
import os
from amftrack.util.sys import (
    get_dates_datetime,
    get_dirname,
    temp_path,
    get_data_info,
    update_plate_info,
    get_current_folders,
    
    get_folders_by_plate_id,
)
from time import time_ns
from amftrack.util.dbx import upload_folders, load_dbx, download, get_dropbox_folders
from datetime import datetime

# %%
directory_targ = directory_project

update_plate_info(directory_targ, local=True)
all_folders = get_current_folders(directory_targ, local=True)
# Out:
# analysed:   0%|          | 0/4815 [00:00<?, ?it/s]

# %%
plates = ["1014_20220525"]

# %%
name_job = f"one_shot_{time_ns()}.sh"
run_launcher('dropbox_downloader.py',[directory_targ,name_job,30],plates,'12:00:00',name_job=name_job)
# Out:
# Submitted batch job 1319371
# sbatch: Single node jobs run on a shared node by default. Add --exclusive if you want to use a node exclusively.
# sbatch: You will be charged for 0.03125 node. A full node consists of 32 CPU cores, 245760 MiB of memory and 0 GPUs and can be shared by up to 32 jobs.

# %%
folders = all_folders.loc[all_folders['unique_id'].isin(plates)]

# %%
folders
# Out:
#                                           total_path Plate PrincePos  \
# 1     /projects/0/einf914/data/20220606_2304_Plate01  1014         1
# 17    /projects/0/einf914/data/20220703_0614_Plate24  1014        24
# 21    /projects/0/einf914/data/20220611_1205_Plate24  1014        24
# 22    /projects/0/einf914/data/20220531_2316_Plate01  1014         1
# 41    /projects/0/einf914/data/20220602_0716_Plate01  1014         1
# ...                                              ...   ...       ...
# 4709  /projects/0/einf914/data/20220701_1213_Plate24  1014        24
# 4712  /projects/0/einf914/data/20220613_1915_Plate24  1014        24
# 4715  /projects/0/einf914/data/20220527_0932_Plate01  1014         1
# 4716  /projects/0/einf914/data/20220529_0627_Plate01  1014         1
# 4723  /projects/0/einf914/data/20220701_0602_Plate24  1014        24
#
#           root strain          medium split Pbait CrossDate Temperature  ...  \
# 1     'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 17    'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 21    'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 22    'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 41    'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# ...        ...    ...             ...   ...   ...       ...         ...  ...
# 4709  'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 4712  'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 4715  'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 4716  'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
# 4723  'Carrot'   'C2'  '001P100N100C'   'Y'   '-'  20220525          25  ...
#
#      /Analysis/transform.mat /Analysis/transform_corrupt.mat  \
# 1                      False                           False
# 17                     False                           False
# 21                     False                           False
# 22                     False                           False
# 41                     False                           False
# ...                      ...                             ...
# 4709                   False                           False
# 4712                   False                           False
# 4715                   False                           False
# 4716                   False                           False
# 4723                   False                           False
#
#      /Analysis/skeleton_realigned_compressed.mat /Analysis/nx_graph_pruned.p  \
# 1                                          False                       False
# 17                                         False                       False
# 21                                         False                       False
# 22                                         False                       False
# 41                                         False                       False
# ...                                          ...                         ...
# 4709                                       False                       False
# 4712                                       False                       False
# 4715                                       False                       False
# 4716                                       False                       False
# 4723                                       False                       False
#
#      /Analysis/nx_graph_pruned_width.p /Analysis/nx_graph_pruned_labeled.p  \
# 1                                False                               False
# 17                               False                               False
# 21                               False                               False
# 22                               False                               False
# 41                               False                               False
# ...                                ...                                 ...
# 4709                             False                               False
# 4712                             False                               False
# 4715                             False                               False
# 4716                             False                               False
# 4723                             False                               False
#
#                     date                 folder      unique_id  \
# 1     06.06.2022, 23:04:  20220606_2304_Plate01  1014_20220525
# 17    03.07.2022, 06:14:  20220703_0614_Plate24  1014_20220525
# 21    11.06.2022, 12:05:  20220611_1205_Plate24  1014_20220525
# 22    31.05.2022, 23:16:  20220531_2316_Plate01  1014_20220525
# 41    02.06.2022, 07:16:  20220602_0716_Plate01  1014_20220525
# ...                  ...                    ...            ...
# 4709  01.07.2022, 12:13:  20220701_1213_Plate24  1014_20220525
# 4712  13.06.2022, 19:15:  20220613_1915_Plate24  1014_20220525
# 4715  27.05.2022, 09:32:  20220527_0932_Plate01  1014_20220525
# 4716  29.05.2022, 06:27:  20220529_0627_Plate01  1014_20220525
# 4723  01.07.2022, 06:02:  20220701_0602_Plate24  1014_20220525
#
#                 datetime
# 1    2022-06-06 23:04:00
# 17   2022-07-03 06:14:00
# 21   2022-06-11 12:05:00
# 22   2022-05-31 23:16:00
# 41   2022-06-02 07:16:00
# ...                  ...
# 4709 2022-07-01 12:13:00
# 4712 2022-06-13 19:15:00
# 4715 2022-05-27 09:32:00
# 4716 2022-05-29 06:27:00
# 4723 2022-07-01 06:02:00
#
# [263 rows x 24 columns]
