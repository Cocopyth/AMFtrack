# %%
# %matplotlib widget
from util.sys import get_path
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from extract_graph import (
    generate_nx_graph,
    transform_list,
    generate_skeleton,
    generate_nx_graph_from_skeleton,
    from_connection_tab,
)
from node_id import reconnect_degree_2
import ast
from plotutil import plot_t_tp1, compress_skeleton
from scipy import sparse
from sparse_util import dilate, zhangSuen
from realign import realign
from datetime import datetime, timedelta
from node_id import orient
import pickle
from matplotlib.widgets import CheckButtons
import scipy.io as sio
import imageio
from pymatreader import read_mat
import os
from matplotlib import colors
from random import choice
from experiment_class_surf import Experiment, clean_exp_with_hyphaes
from hyphae_id import (
    clean_and_relabel,
    get_mother,
    save_hyphaes,
    resolve_ambiguity_two_ends,
    solve_degree4,
    clean_obvious_fake_tips,
)
from extract_graph import prune_graph
from skimage.measure import profile_line
import math
from Analysis.util import *
from directory import directory, path_code
from Analysis.data_info import *
from extract_width_fun import *
from util.sys import get_path, get_dates_datetime, get_dirname, temp_path
import pickle

# %%
directory = "/projects/0/einf914/data/"

# %%
plate = 40
t = 37
begin = t
end = t
dates_datetime = get_dates_datetime(directory, plate)
dates_datetime.sort()
dates_datetime_chosen = dates_datetime[begin : end + 1]
dates = dates_datetime_chosen
exp = Experiment(directory)
exp.load(dates, False)

# %%
# exp = get_exp((40,0,37),directory)
# exp_copy = Experiment(40,directory)
# Out:
# begin = 2020-11-19 20:21:00
#   end = 2020-11-25 18:06:00

# %%
edge_test = get_width_info(exp, 0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1173b635d400> in <module>
# ----> 1 edge_test = get_width_info(exp,0)
#
# /nfs/home2/cbisot/pycode/MscThesis/extract_width_fun.py in get_width_info(experiment, t, resolution)
#     131 #         print(edge)
#     132         edge_exp = Edge(Node(edge[0],experiment),Node(edge[1],experiment),experiment)
# --> 133         mean = np.mean(list(get_width_edge(edge_exp,resolution,t).values()))
#     134 #         print(np.mean(list(get_width_edge(edge_exp,resolution,t).values())))
#     135         edge_width[edge]=mean
#
# /nfs/home2/cbisot/pycode/MscThesis/extract_width_fun.py in get_width_edge(edge, resolution, t, local, threshold_averaging)
#     118         _,after = get_source_image(edge.experiment,pixels[i+2],t,local,pivot)
#     119 #         plot_t_tp1([0,1,2],[],{0 : pivot,1 : before, 2 : after},None,source_img,source_img)
# --> 120         width = get_width_pixel(edge,index,source_img,pivot,before,after,t,threshold_averaging = threshold_averaging)
#     121 #         print(width*pixel_conversion_factor)
#     122         widths[pixel_list[index]]=width*pixel_conversion_factor
#
# /nfs/home2/cbisot/pycode/MscThesis/extract_width_fun.py in get_width_pixel(edge, index, im, pivot, before, after, t, size, width_factor, averaging_size, threshold_averaging)
#      53     point1=point1.astype(int)
#      54     point2=point2.astype(int)
# ---> 55     p = profile_line(imtab, point1, point2,mode='constant')
#      56 #     fig = plt.figure()
#      57 #     ax = fig.add_subplot(111)
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/skimage/measure/profile.py in profile_line(image, src, dst, linewidth, order, mode, cval, reduce_func)
#     102         mode = 'constant'
#     103
# --> 104     perp_lines = _line_profile_coordinates(src, dst, linewidth=linewidth)
#     105     if image.ndim == 3:
#     106         pixels = [ndi.map_coordinates(image[..., i], perp_lines,
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/skimage/measure/profile.py in _line_profile_coordinates(src, dst, linewidth)
#     171                                       linewidth) for row_i in line_row])
#     172     perp_cols = np.array([np.linspace(col_i - col_width, col_i + col_width,
# --> 173                                       linewidth) for col_i in line_col])
#     174     return np.array([perp_rows, perp_cols])
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/skimage/measure/profile.py in <listcomp>(.0)
#     171                                       linewidth) for row_i in line_row])
#     172     perp_cols = np.array([np.linspace(col_i - col_width, col_i + col_width,
# --> 173                                       linewidth) for col_i in line_col])
#     174     return np.array([perp_rows, perp_cols])
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     150         step = NaN
#     151         # Multiply with delta to allow possible override of output class.
# --> 152         y = y * delta
#     153
#     154     y += start
#
# KeyboardInterrupt:

# %%
G = exp.nx_graph[0]
# nx.set_edge_attributes(G, edge_test, 'width')

# %%
G

# %%
G.edges(data=True)
# Out:
# EdgeDataView([(14, 20, {'weight': 468, 'pixel_list': [(19804, 5152), (19804, 5153), (19805, 5154), (19806, 5154), (19807, 5155), (19807, 5156), (19808, 5156), (19809, 5157), (19810, 5158), (19810, 5159), (19811, 5159), (19812, 5160), (19813, 5161), (19814, 5162), (19815, 5163), (19816, 5164), (19817, 5164), (19817, 5165), (19818, 5166), (19819, 5166), (19819, 5167), (19820, 5167), (19821, 5168), (19821, 5169), (19822, 5169), (19823, 5170), (19824, 5171), (19825, 5172), (19826, 5173), (19827, 5174), (19828, 5174), (19828, 5175), (19829, 5176), (19830, 5177), (19831, 5178), (19832, 5178), (19832, 5179), (19833, 5179), (19833, 5180), (19834, 5180), (19834, 5181), (19835, 5181), (19836, 5182), (19837, 5182), (19837, 5183), (19838, 5184), (19839, 5185), (19840, 5185), (19840, 5186), (19841, 5187), (19842, 5188), (19843, 5188), (19843, 5189), (19844, 5189), (19845, 5190), (19846, 5191), (19847, 5192), (19848, 5193), (19849, 5194), (19850, 5195), (19851, 5196), (19851, 5197), (19852, 5197), (19853, 5198), (19854, 5199), (19854, 5200), (19855, 5200), (19855, 5201), (19856, 5201), (19856, 5202), (19857, 5202), (19857, 5203), (19858, 5203), (19858, 5204), (19859, 5204), (19859, 5205), (19860, 5205), (19860, 5206), (19861, 5206), (19861, 5207), (19862, 5207), (19862, 5208), (19863, 5208), (19863, 5209), (19864, 5209), (19864, 5210), (19865, 5211), (19866, 5211), (19866, 5212), (19867, 5212), (19867, 5213), (19868, 5213), (19868, 5214), (19869, 5214), (19869, 5215), (19870, 5215), (19870, 5216), (19871, 5216), (19871, 5217), (19872, 5218), (19873, 5219), (19874, 5220), (19875, 5220), (19875, 5221), (19876, 5221), (19876, 5222), (19877, 5223), (19878, 5224), (19879, 5224), (19879, 5225), (19880, 5226), (19881, 5227), (19882, 5228), (19883, 5229), (19884, 5229), (19884, 5230), (19884, 5231), (19885, 5231), (19886, 5232), (19887, 5233), (19888, 5234), (19889, 5235), (19890, 5235), (19890, 5236), (19891, 5236), (19891, 5237), (19892, 5238), (19893, 5239), (19893, 5240), (19894, 5240), (19894, 5241), (19895, 5242), (19896, 5243), (19897, 5243), (19897, 5244), (19898, 5245), (
, 1923, 4549, 4539, 1977, 4236, 4258, 3903, 4564, 4508, 4521, 4525, 4552, 4518, 4566, 4546, 3952, 3894, 4536, 4560, 3831, 3836, 3808, 3865, 3862, 3864, 5849, 5853, 5693, 1966, 3898, 5490, 5537, 2069, 2091, 1867, 1784, 3678, 3902, 1795, 2073, 2061, 5780, 5897, 3524, 3469, 5716, 6135, 3474, 3395, 3400, 1837, 1790, 4302, 4283, 3434, 3430, 3422, 2994, 2992, 3439, 2995, 2985, 3431, 3403, 2953, 3006, 3413, 5719, 5644, 3009, 4254, 4261, 4281, 4282, 4284, 4273, 4862, 4875, 4884, 2784, 2780, 3398, 4864, 7797, 7774, 3393, 7780, 3453, 7524, 5502, 4837, 4886, 5443, 5506, 3004, 3024, 3011, 3049, 3015, 4878, 2940, 2969, 4742, 4765, 4744, 4774, 5642, 2835, 2777, 4240, 4268, 4223, 4235, 2977, 2850, 2991, 2980, 2981, 3013, 2996, 3039, 3657, 2843, 7468, 7516, 5900, 7140, 7474, 1770, 3699, 6983, 6963, 2813, 2846, 3294, 1761, 3014, 3016, 2990, 3739, 3710, 4736, 7130, 4522, 4851, 7820, 7813, 2825, 2888, 6973, 6783, 6922, 3709, 7755, 7822, 3735, 4468, 6934, 7024, 7472, 2815, 3731, 3736, 6927, 6924, 2821, 1752, 7124,  ...

# %%
# exp_copy.copy(exp)
# labels = {node for g in exp_copy.nx_graph for node in g}
# exp_copy.nodes=[]
# for label in labels:
#     exp_copy.nodes.append(Node(label,exp_copy))

# %%
plt.close("all")
edge_exp.end.show_source_image(10, 10)
edge_exp.begin.show_source_image(10, 10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
edge = choice(list(exp.nx_graph[10].edges))
edge_exp = Edge(Node(edge[0], exp), Node(edge[1], exp), exp)
# edge_exp = Edge(Node(366,exp),Node(188,exp),exp)

# %%
plt.close("all")

get_width_edge(edge_exp, 50, 10, False, threshold_averaging=5)
# Out:
# {(18459, 12394): 37.459527746733066}

# %%
def get_source_image(experiment, pos, t, local, force_selection=None):
    x, y = pos[0], pos[1]
    ims, posimg = experiment.find_image_pos(x, y, t, local)
    if force_selection is None:
        dist_border = [
            min([posimg[1][i], 3000 - posimg[1][i], posimg[0][i], 4096 - posimg[0][i]])
            for i in range(posimg[0].shape[0])
        ]
        j = np.argmax(dist_border)
    else:
        dist_last = [
            np.linalg.norm(
                np.array((posimg[1][i], posimg[0][i])) - np.array(force_selection)
            )
            for i in range(posimg[0].shape[0])
        ]
        j = np.argmin(dist_last)
    return (ims[j], (posimg[1][j], posimg[0][j]))

# %%
def get_width_pixel(
    edge,
    index,
    im,
    pivot,
    before,
    after,
    t,
    size=20,
    width_factor=60,
    averaging_size=100,
    threshold_averaging=10,
):
    imtab = im
    #     print(imtab.shape)
    #     print(int(max(0,pivot[0]-averaging_size)),int(pivot[0]+averaging_size))
    threshold = np.mean(
        imtab[
            int(max(0, pivot[0] - averaging_size)) : int(pivot[0] + averaging_size),
            int(max(0, pivot[1] - averaging_size)) : int(pivot[1] + averaging_size),
        ]
        - threshold_averaging
    )
    orientation = np.array(before) - np.array(after)
    perpendicular = (
        [1, -orientation[0] / orientation[1]] if orientation[1] != 0 else [0, 1]
    )
    perpendicular_norm = np.array(perpendicular) / np.sqrt(
        perpendicular[0] ** 2 + perpendicular[1] ** 2
    )
    point1 = np.around(np.array(pivot) + width_factor * perpendicular_norm)
    point2 = np.around(np.array(pivot) - width_factor * perpendicular_norm)
    point1 = point1.astype(int)
    point2 = point2.astype(int)
    #     p = profile_line(imtab, point1, point2,mode='constant')
    #     fig = plt.figure()
    #     ax = fig.add_subplot(111)
    #     ax.plot(p)
    #     derivative = [p[i+1]-p[i] for i in range(len(p)-1)]
    #     fig = plt.figure()
    #     ax = fig.add_subplot(111)
    #     ax.plot([np.mean(derivative[5*i:5*i+5]) for i in range(len(derivative)//5)])
    problem = False
    arg = len(p) // 2
    if p[arg] > threshold:
        arg = np.argmin(p)
    #     we_plot=randrange(1000)
    while p[arg] <= threshold:
        if arg <= 0:
            #             we_plot=50
            problem = True
            break
        arg -= 1
    begin = arg
    arg = len(p) // 2
    if p[arg] > threshold:
        arg = np.argmin(p)
    while p[arg] <= threshold:
        if arg >= len(p) - 1:
            #             we_plot=50
            problem = True
            break
        arg += 1
    end = arg
    #     print(end-begin,len(p))
    return np.linalg.norm(point1 - point2) * (end - begin) / len(p)

# %%
def get_width_edge(edge, resolution, t, local=False, threshold_averaging=10):
    pixel_conversion_factor = 1.725
    pixel_list = edge.pixel_list(t)
    pixels = []
    indexes = []
    source_images = []
    poss = []
    widths = {}
    if len(pixel_list) > 3 * resolution:
        for i in range(0, len(pixel_list) // resolution):
            index = i * resolution
            indexes.append(index)
            pixel = pixel_list[index]
            pixels.append(pixel)
            source_img, pos = get_source_image(edge.experiment, pixel, t, local)
            source_images.append(source_img)
            poss.append(pos)
    else:
        indexes = [0, len(pixel_list) // 2, len(pixel_list) - 1]
        for index in indexes:
            pixel = pixel_list[index]
            pixels.append(pixel)
            source_img, pos = get_source_image(edge.experiment, pixel, t, local)
            source_images.append(source_img)
            poss.append(pos)
    #     print(indexes)
    for i, index in enumerate(indexes[1:-1]):
        source_img = source_images[i + 1]
        pivot = poss[i + 1]
        _, before = get_source_image(edge.experiment, pixels[i], t, local, pivot)
        _, after = get_source_image(edge.experiment, pixels[i + 2], t, local, pivot)
        plot_t_tp1(
            [0, 1, 2], [], {0: pivot, 1: before, 2: after}, None, source_img, source_img
        )
        width = get_width_pixel(
            edge,
            index,
            source_img,
            pivot,
            before,
            after,
            t,
            threshold_averaging=threshold_averaging,
        )
        #         print(width*pixel_conversion_factor)
        widths[pixel_list[index]] = width * pixel_conversion_factor
    edge.experiment.nx_graph[t].get_edge_data(edge.begin.label, edge.end.label)[
        "width"
    ] = widths
    return widths

# %%
def get_width_info(experiment, t, resolution=50):
    edge_width = {}
    graph = experiment.nx_graph[t]
    #     print(len(list(graph.edges)))
    for edge in graph.edges:
        #         print(edge)
        edge_exp = Edge(
            Node(edge[0], experiment), Node(edge[1], experiment), experiment
        )
        mean = np.mean(list(get_width_edge(edge_exp, resolution, t).values()))
        print(np.mean(list(get_width_edge(edge_exp, resolution, t).values())))
        edge_width[edge] = mean
    return edge_width

# %%
max_width = np.max(list(edge_test.values()))
max_width
# Out:
#        [4.53677e-01, 2.75500e-03, 6.60310e-01, 1.00000e+00],
#        [5.12206e-01, 1.88330e-02, 6.55209e-01, 1.00000e+00],
#        [4.65550e-01, 4.54500e-03, 6.60139e-01, 1.00000e+00],
#        [3.87183e-01, 1.43400e-03, 6.54177e-01, 1.00000e+00],
#        [3.99411e-01, 8.59000e-04, 6.56133e-01, 1.00000e+00],
#        [4.17642e-01, 5.64000e-04, 6.58390e-01, 1.00000e+00],
#        [4.35734e-01, 1.12700e-03, 6.59797e-01, 1.00000e+00],
#        [3.18856e-01, 7.57600e-03, 6.37640e-01, 1.00000e+00],
#        [4.29719e-01, 8.31000e-04, 6.59425e-01, 1.00000e+00],
#        [4.35734e-01, 1.12700e-03, 6.59797e-01, 1.00000e+00],
#        [5.95011e-01, 7.71900e-02, 6.27917e-01, 1.00000e+00],
#        [4.17642e-01, 5.64000e-04, 6.58390e-01, 1.00000e+00],
#        [4.41732e-01, 1.54000e-03, 6.60069e-01, 1.00000e+00],
#        [3.06210e-01, 8.90200e-03, 6.33694e-01, 1.00000e+00],
#        [2.34715e-01, 1.55020e-02, 6.07592e-01, 1.00000e+00],
#        [4.53677e-01, 2.75500e-03, 6.60310e-01, 1.00000e+00],
#        [4.23689e-01, 6.46000e-04, 6.58956e-01, 1.00000e+00],
#        [2.93478e-01, 1.02130e-02, 6.29490e-01, 1.00000e+00],
#        [3.50150e-01, 4.38200e-03, 6.46298e-01, 1.00000e+00],
#        [2.14350e-01, 1.69730e-02, 5.99239e-01, 1.00000e+00],
#        [3.18856e-01, 7.57600e-03, 6.37640e-01, 1.00000e+00],
#        [4.47714e-01, 2.08000e-03, 6.60240e-01, 1.00000e+00],
#        [5.03830e-02, 2.98030e-02, 5.27975e-01, 1.00000e+00],
#        [3.74897e-01, 2.24500e-03, 6.51876e-01, 1.00000e+00],
#        [5.03830e-02, 2.98030e-02, 5.27975e-01, 1.00000e+00],
#        [2.54627e-01, 1.38820e-02, 6.15419e-01, 1.00000e+00],
#        [5.03830e-02, 2.98030e-02, 5.27975e-01, 1.00000e+00],
#        [4.11580e-01, 5.77000e-04, 6.57730e-01, 1.00000e+00]])

# %%
plt.close("all")
t = 0
fig = plt.figure()
ax = fig.add_subplot(111)
graph = exp.nx_graph[t]
for edge in graph.edges:
    edge_exp = Edge(Node(edge[0], exp), Node(edge[1], exp), exp)
    begin = edge_exp.begin.pos(t)
    end = edge_exp.end.pos(t)
    ax.plot(
        (begin[1], end[1]),
        (begin[0], end[0]),
        color=plt.cm.get_cmap("plasma")(edge_test[edge] / 60),
    )
# plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
exp.plot_raw(0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
edge_test.experiment.nx_graph[t].get_edge_data(
    edge_test.begin.label, edge_test.end.label
)

# %%
plt.close("all")
get_width_edge(edge_test, 50, 4, True, threshold_averaging=5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (3000, 4096)
# 1711 1911
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 24 143.053775
# {(8717, 7032): 40.86386931802906}

# %%
exp_2.plot([4], [[edge_test.end.label, edge_test.begin.label]])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# node = choice(exp_2.nodes)
# node.ts()

# %%
edge_test
# Out:
# Edge(1679,1823)

# %%
edge_test = node.neighbours(4)[0].edges(4)[0].end.edges(4)[0]
