# %% [markdown]
# ***Load modules***
# This will require amtrack repo in the right path I use environment variables but feel free to do something better.
# Normally all the required packages are indicated, if some are missing, please add them.
# If you also want to create a "freeze" or a poetry thing to have an easier installation of the environment please do so.

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
import os  
import sys  
sys.path.insert(0, os.getenv('HOME')+'/pycode/MscThesis/')
# sys.path.insert(0,r'C:\Users\coren\Documents\PhD\Code\AMFtrack')

import pandas as pd
from amftrack.util.sys import get_dates_datetime, get_dirname, get_data_info, update_plate_info, \
get_current_folders, get_folders_by_plate_id


import ast
from amftrack.plotutil import plot_t_tp1
from scipy import sparse
from datetime import datetime
import pickle
import scipy.io as sio
from pymatreader import read_mat
from matplotlib import colors
import cv2
import imageio
import matplotlib.pyplot as plt
import numpy as np
from skimage.filters import frangi
from skimage import filters
from random import choice
import scipy.sparse
import os
from amftrack.pipeline.functions.image_processing.extract_graph import from_sparse_to_graph, generate_nx_graph, sparse_to_doc
from skimage.feature import hessian_matrix_det
from amftrack.pipeline.functions.image_processing.experiment_class_surf import Experiment, Edge,Node, plot_raw_plus
from amftrack.pipeline.paths.directory import run_parallel_transfer, find_state, directory_scratch, directory_project, directory_archive
import dropbox
from amftrack.transfer.functions.transfer import upload, zip_file, sync_fold
from subprocess import call
from tqdm.autonotebook import tqdm
from time import time_ns
import subprocess
import matplotlib as mpl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ***choose the path of interest***
# I mounted sun on my linux computer at AMOLF. Please feel free to do so on yours as well. I can send you the command.
# Otherwise, if you have the folders locally, just indicate the path.
# Finally you can also simply ssh to my computer and run things from there.

# %%
directory = r'/mnt/sun-temp/TEMP/PRINCE_felix/'

update_plate_info(directory)
all_folders = get_current_folders(directory)
len(folders)
# Out:
# analysed:   0%|          | 0/1 [00:00<?, ?it/s]
# 1

# %% [markdown]
# ***Choose the folder you're interested in***

# %%
folders = all_folders.loc[all_folders['folder']=='20220330_2357_Plate19']

# %%
folders
# Out:
#                                              total_path Plate PrincePos  \
# 8245  /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_...   961        19
#
#           root strain          medium split Pbait CrossDate Temperature  ...  \
# 8245  'Carrot'   'A5'  '001P100N100C'   'Y'   '-'  20220328          25  ...
#
#      /Analysis/skeleton_masked_compressed.mat  \
# 8245                                    False
#
#      /Analysis/skeleton_pruned_compressed.mat /Analysis/transform.mat  \
# 8245                                    False                   False
#
#      /Analysis/transform_corrupt.mat  \
# 8245                           False
#
#      /Analysis/skeleton_realigned_compressed.mat /Analysis/nx_graph_pruned.p  \
# 8245                                       False                       False
#
#      /Analysis/nx_graph_pruned_width.p /Analysis/nx_graph_pruned_labeled.p  \
# 8245                             False                               False
#
#                     date                 folder
# 8245  30.03.2022, 23:57:  20220330_2357_Plate19
#
# [1 rows x 22 columns]

# %% [markdown]
# These are local adaptations of functions for running things on the supercomputer. So better to keep them in the notebook at this stage.

# %%
path_code = os.getenv('HOME')+"/pycode/MscThesis/"

def make_stitching_loop(directory,dirname,op_id):
    a_file = open(f'{path_code}amftrack/pipeline/scripts/stitching_loops/stitching_loop.ijm',"r")

    list_of_lines = a_file.readlines()

    list_of_lines[4] = f'mainDirectory = \u0022{directory}\u0022 ;\n'
    list_of_lines[29] = f'\t if(startsWith(list[i],\u0022{dirname}\u0022)) \u007b\n'
    file_name = f'{os.getenv("TEMP")}/stitching_loops/stitching_loop{op_id}.ijm'
    a_file = open(file_name, "w")

    a_file.writelines(list_of_lines)

    a_file.close()
    
def run_stitch(directory, folders):
    folder_list = list(folders['folder'])
    folder_list.sort()    
    with tqdm(total=len(folder_list), desc="stitched") as pbar:
        for folder in folder_list:
            op_id = time_ns()
            im = imageio.imread(f'{directory}/{folder}/Img/Img_r03_c05.tif')
            for x in range(1,11):
                for y in range(1,16):
                    strix= str(x) if x>=10 else f'0{x}'
                    striy= str(y) if y>=10 else f'0{y}'
                    path = f'{directory}/{folder}/Img/Img_r{strix}_c{striy}.tif'
                    # print(striy,path,os.path.getsize(path))
                    if not os.path.isfile(path):
                        f = open(path, 'w')
                    if os.path.getsize(path)==0:
                        imageio.imwrite(path,im*0)
            make_stitching_loop(directory,folder,op_id)
            command = [os.getenv('HOME')+'/Fiji.app/ImageJ-linux64','--mem=8000m','--headless','--ij2','--console','-macro',f'{os.getenv("TEMP")}/stitching_loops/stitching_loop{op_id}.ijm']
            print(' '.join(command))
            process = subprocess.run(command)
            pbar.update(1)
            
def run_parallel(code, args, folders):
    op_id = time_ns()
    folders.to_json(f'{os.getenv("TEMP")}/{op_id}.json')# temporary file
    folder_list = list(folders['folder'])
    folder_list.sort()  
    args_str = [str(arg) for arg in args]
    arg_str = " ".join(args_str)
    with tqdm(total=len(folder_list), desc="stitched") as pbar:
        for index,folder in enumerate(folder_list):
            command = ['python',f'{path_code}amftrack/pipeline/scripts/image_processing/{code}']+args_str+[f'{op_id}',f'{index}']
            print(' '.join(command))
            process = subprocess.run(command)
            pbar.update(1)

# %% [markdown]
# ***Stitch the folders you're interested in***
#
# should take about 20mins

# %%
run_stitch(directory,folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/ipausers/bisot/Fiji.app/ImageJ-linux64 --mem=8000m --headless --ij2 --console -macro /home/ipausers/bisot/temp//stitching_loops/stitching_loop1648810566105623944.ijm
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# Java HotSpot(TM) 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# 20220330_2357_Plate19/
# (Fri Apr 01 12:58:52 CEST 2022): Stitching the following files:
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c01.tif' Imp: 'null' Offset: (0.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c02.tif' Imp: 'null' Offset: (3276.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c03.tif' Imp: 'null' Offset: (6552.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c04.tif' Imp: 'null' Offset: (9828.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c05.tif' Imp: 'null' Offset: (13104.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c06.tif' Imp: 'null' Offset: (16380.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c07.tif' Imp: 'null' Offset: (19656.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c08.tif' Imp: 'null' Offset: (22932.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c09.tif' Imp: 'null' Offset: (26208.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c10.tif' Imp: 'null' Offset: (29484.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c11.tif' Imp: 'null' Offset: (32760.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c12.tif' Imp: 'null' Offset: (36036.0, 0.0)
# Image: '/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_
# 115 overlaps 116: 0.39631714301974535 translation: x: 3451 y: -8
# 115 overlaps 129: 0.26669799552077855 translation: x: -3460 y: 2571
# 115 overlaps 130: 0.3245418294889271 translation: x: -11 y: 2551
# 115 overlaps 131: 0.16752476476246334 translation: x: 3443 y: 2546
# 116 overlaps 117: 0.41670468054282994 translation: x: 3448 y: -14
# 116 overlaps 130: 0.3083649885385145 translation: x: -3457 y: 2567
# 116 overlaps 131: 0.4988415107463875 translation: x: -13 y: 2559
# 116 overlaps 132: 0.46648917588694855 translation: x: 3439 y: 2542
# 117 overlaps 118: 0.24391322102022706 translation: x: 3442 y: -9
# 117 overlaps 131: 0.482012335976121 translation: x: -3467 y: 2573
# 117 overlaps 132: 0.40525910499900286 translation: x: -12 y: 2560
# 117 overlaps 133: 0.14619866029015569 translation: x: 3428 y: 2543
# 118 overlaps 119: 0.050099091339415376 translation: x: 3442 y: -17
# 118 overlaps 132: 0.24067816859593597 translation: x: -3449 y: 2567
# 118 overlaps 133: 0.1785673953448456 translation: x: -12 y: 2560
# 118 overlaps 134: 0.3578881715081959 translation: x: 3423 y: 2545
# 119 overlaps 133: 0.40267609528708154 translation: x: -3448 y: 2574
# 119 overlaps 134: 0.6574986741583903 translation: x: -12 y: 2560
# 120 overlaps 121: 0.49999364106635824 translation: x: 3307 y: -16
# 120 overlaps 135: 0.3128365786701511 translation: x: -281 y: 2378
# 120 overlaps 136: 0.14669241232618863 translation: x: 3217 y: 2390
# 121 overlaps 122: 0.22683910627752835 translation: x: 3446 y: -34
# 121 overlaps 135: 0.1260996130523554 translation: x: -3735 y: 2496
# 121 overlaps 136: 0.2852610913511968 translation: x: -123 y: 2365
# 121 overlaps 137: 0.013858496508563302 translation: x: 3261 y: 2384
# 122 overlaps 123: 0.2512243434644417 translation: x: 3296 y: 361
# 122 overlaps 136: 0.057256719629631414 translation: x: -3676 y: 2332
# 122 overlaps 137: 0.8524645416246365 translation: x: -116 y: 2358
# 122 overlaps 138: 0.6315884497731609 translation: x: 3392 y: 2333
# ...
#   average displacement: 7.080px
#   minimal displacement: 0.000px
#   maximal displacement: 25.140px
# maxError more than 6.0 times bigger than avgerror.
# Identified link between /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c08.tif and /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c07.tif (R=0.46901292719965654) to be bad. Reoptimizing.
# Tile size: 128
# Number of tile graphs = 1
# Successfully optimized configuration of 128 tiles after 5396 iterations:
#   average displacement: 6.739px
#   minimal displacement: 0.000px
#   maximal displacement: 23.332px
# maxError more than 6.0 times bigger than avgerror.
# Identified link between /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r07_c15.tif and /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r08_c14.tif (R=0.1269234053751347) to be bad. Reoptimizing.
# Tile size: 128
# Number of tile graphs = 1
# Successfully optimized configuration of 128 tiles after 5398 iterations:
#   average displacement: 6.404px
#   minimal displacement: 0.000px
#   maximal displacement: 20.243px
# maxError more than 6.0 times bigger than avgerror.
# Identified link between /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c04.tif and /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c05.tif (R=0.5820161074398429) to be bad. Reoptimizing.
# Tile size: 128
# Number of tile graphs = 1
# Successfully optimized configuration of 128 tiles after 5477 iterations:
#   average displacement: 5.838px
#   minimal displacement: 0.000px
#   maximal displacement: 20.207px
#  image information list size =128
# (Fri Apr 01 13:02:54 CEST 2022): Final image positions in the fused image:
# Tile 4 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c05.tif): 0.0, 0.0
# Tile 5 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c06.tif): 3252.0, -1.0
# Tile 6 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c07.tif): 6881.113, -212.17432
# Tile 7 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c08.tif): 10313.581, -239.51953
# Tile 8 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c09.tif): 13762.749, -262.1754
# Tile 9 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c10.tif): 17213.477, -299.57812
# Tile 10 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r01_c11.tif): 20832.32, -166.56372
# Tile 18 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c04.tif): -3276.602, 2379.5444
# Tile 19 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c05.tif): 16.346558, 2363.7817
# Tile 20 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c06.tif): 3444.185, 2346.9976
# Tile 21 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c07.tif): 6867.6836, 2330.0435
# Tile 22 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c08.tif): 10299.625, 2306.4539
# Tile 23 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c09.tif): 13746.106, 2289.3604
# Tile 24 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c10.tif): 17199.926, 2252.2031
# Tile 25 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c11.tif): 20654.385, 2234.5366
# Tile 26 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r02_c12.tif): 24111.332, 2215.4512
# Tile 32 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c03.tif): -6742.01, 4931.014
# Tile 33 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c04.tif): -3428.274, 4919.442
# Tile 34 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c05.tif): 4.5091553, 4903.4663
# Tile 35 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c06.tif): 3430.7253, 4887.543
# Tile 36 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c07.tif): 6848.5596, 4871.089
# Tile 37 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c08.tif): 10282.947, 4848.327
# Tile 38 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c09.tif): 13731.342, 4830.7446
# Tile 39 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c10.tif): 17188.281, 4836.9595
# Tile 40 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c11.tif): 20643.45, 4783.8013
# Tile 41 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c12.tif): 24098.014, 4767.7744
# Tile 42 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r03_c13.tif): 27561.826, 4755.3584
# Tile 46 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c02.tif): -10166.3545, 7523.8647
# Tile 47 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c03.tif): -6881.184, 7504.4595
# Tile 48 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c04.tif): -3441.5889, 7488.9414
# Tile 49 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c05.tif): -11.61676, 7471.9365
# Tile 50 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c06.tif): 3407.1626, 7453.417
# Tile 51 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c07.tif): 6827.7993, 7424.5337
# Tile 52 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c08.tif): 10261.054, 7414.1987
# Tile 53 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c09.tif): 13722.823, 7396.573
# Tile 54 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c10.tif): 17177.69, 7366.6533
# Tile 55 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c11.tif): 20629.521, 7351.664
# Tile 56 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c12.tif): 24079.887, 7335.412
# Tile 57 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c13.tif): 27531.025, 7317.5947
# Tile 58 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r04_c14.tif): 30968.615, 7303.242
# Tile 61 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c02.tif): -10187.284, 10086.14
# Tile 62 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c03.tif): -6887.2437, 10068.621
# Tile 63 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c04.tif): -3462.454, 10058.871
# Tile 64 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c05.tif): -28.950317, 10037.583
# Tile 65 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c06.tif): 3402.3892, 10009.637
# Tile 66 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c07.tif): 6822.2817, 9985.202
# Tile 67 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c08.tif): 10260.485, 9969.805
# Tile 68 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c09.tif): 13713.135, 9950.781
# Tile 69 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c10.tif): 17167.285, 9932.836
# Tile 70 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c11.tif): 20620.258, 9912.49
# Tile 71 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c12.tif): 24073.627, 9899.768
# Tile 72 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c13.tif): 27519.938, 9883.866
# Tile 73 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r05_c14.tif): 30956.746, 9867.872
# Tile 75 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r06_c01.tif): -13346.358, 12618.086
# Tile 76 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r06_
(/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r09_c15.tif): 34357.246, 20077.037
# Tile 135 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c01.tif): -13638.324, 22735.3
# Tile 136 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c02.tif): -10526.324, 22698.3
# Tile 137 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c03.tif): -7076.9873, 22647.918
# Tile 138 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c04.tif): -3571.6106, 22624.734
# Tile 139 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c05.tif): -177.65234, 22615.318
# Tile 140 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c06.tif): 3268.5212, 22594.195
# Tile 141 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c07.tif): 6709.4756, 22583.39
# Tile 142 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c08.tif): 10157.911, 22563.406
# Tile 143 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c09.tif): 13630.195, 22548.824
# Tile 144 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c10.tif): 17097.598, 22520.287
# Tile 145 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c11.tif): 20550.68, 22494.71
# Tile 146 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c12.tif): 24000.645, 22484.645
# Tile 147 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c13.tif): 27461.084, 22469.342
# Tile 148 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c14.tif): 30915.13, 22458.312
# Tile 149 (/mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Img2/Img_r10_c15.tif): 34350.27, 22444.152
# (Fri Apr 01 13:02:54 CEST 2022): Size of bounding box for output image: 52201.992, 26034.879
# Linear Blending Fusion started.
# (Fri Apr 01 13:05:28 CEST 2022): Finished Stitching.
# Saving /mnt/sun-temp/TEMP/PRINCE_felix//20220330_2357_Plate19//Stitched Image_1.tif ...
# Saved
# Image grid sequence stitching is done!
# 1

# %% [markdown]
# ***Compress the image and skeletonize***
#
# should take 1h30-2h

# %%
args = [directory]
run_parallel('compress_image.py',args, folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/compress_image.py /mnt/sun-temp/TEMP/PRINCE_felix/ 1648811165598522091 0
# Directory  /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_Plate19/Analysis  Created

# %%
time = '3:00:00'
low = 30
high = 80
extend = 30
args=[low, high, extend,directory]
run_parallel('extract_skel.py',args,folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/extract_skel.py 30 80 30 /mnt/sun-temp/TEMP/PRINCE_felix/ 1648811201216645914 0
# ['20220330_2357_Plate19']
# Directory  /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_Plate19/Analysis  already exists
# number to reduce :  8813355 1407399775
# time= 3948.9146938323975

# %% [markdown]
# ***Visualise the skeletonization***

# %%
select = folders
folder_list = list(select['total_path'])
folder_list.sort()
skels = []
ims = []
kernel = np.ones((5,5),np.uint8)
itera = 2
start = 0

finish = start+2
for folder in folder_list[start:finish]:
    path_snap=folder
    skel_info = read_mat(path_snap+'/Analysis/skeleton_compressed.mat')
    skel = skel_info['skeleton']
    skels.append(cv2.dilate(skel.astype(np.uint8),kernel,iterations = itera))
    im = read_mat(path_snap+'/Analysis/raw_image.mat')['raw']
    ims.append(im)

# %%
plt.close('all')
start = 0
finish = start + 1
for i in range(start,finish):
    plot_t_tp1([], [], None, None, skels[i]>0, ims[i])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ***These steps may be a bit long, but it also helps just keeping things consistent and use one single framework,*** you may bypass them by artificially renaming skeleton.mat into skeleton_realigned.mat which is necessary for the next step because you probably don't care about these two steps since you're doing only one image...

# %%
time = '2:00'
thresh = 50
args=[thresh, directory]
run_parallel('mask_skel.py',args,folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/mask_skel.py 50 /mnt/sun-temp/TEMP/PRINCE_felix/ 1648816134424986144 0
# Directory  /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_Plate19/Analysis  already exists

# %%
time = '3:00:00'
threshold = 0.1
args = [threshold, directory]
run_parallel('prune_skel.py',args,folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/prune_skel.py 0.1 /mnt/sun-temp/TEMP/PRINCE_felix/ 1648816176163751129 0
# [0.19695, 0.321024, 206.3131, 0.30624, 1.282572, 0.233972]
# cleaning, number of nodes before 1483
# number of unsolved cases 158
# number of unsolved cases 120
# number of unsolved cases 110
# number of unsolved cases 108
# end cleaning, number of nodes after 1258

# %%
plates = list(set(list(folders['Plate'].values)))
for plate in plates:
    time = '2:00:00'
    args = [directory]
    run_parallel('realign.py', args, folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/realign.py /mnt/sun-temp/TEMP/PRINCE_felix/ 1648818746428804634 0
# saving 0 /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_Plate19

# %% [markdown]
# Now you're finally getting to the point where you generate the graph object

# %%
time = '2:00:00'
args=[directory]
run_parallel('extract_nx_graph.py',args, folders)
# Out:
# stitched:   0%|          | 0/1 [00:00<?, ?it/s]
# python /home/ipausers/bisot/pycode/MscThesis/amftrack/pipeline/scripts/image_processing/extract_nx_graph.py /mnt/sun-temp/TEMP/PRINCE_felix/ 1648818779236444471 0
# ['20220330_2357_Plate19']
# cleaning, number of nodes before 1056
# number of unsolved cases 88
# number of unsolved cases 80
# number of unsolved cases 78
# number of unsolved cases 78
# end cleaning, number of nodes after 1019
# /mnt/sun-temp/TEMP/PRINCE_felix/20220330_2357_Plate19/Analysis/nx_graph_pruned.p

# %% [markdown]
# ***and now you have the Experiment object to play with and query images related to position of edges etc...***

# %%
run_info = folders
plate = int(list(run_info['folder'])[i].split('_')[-1][5:])
folder_list = list(run_info['folder'])
directory_name = folder_list[i]
exp = Experiment(plate,directory)
exp.load(run_info.loc[run_info['folder']==directory_name],labeled=False)
path_snap = directory + directory_name
(G, pos) = exp.nx_graph[0],exp.positions[0]

# %%
from random import choice
edge = choice(list(G.edges))

# %%
edge_exp = Edge(Node(edge[0],exp),Node(edge[1],exp),exp)

# %% [markdown]
# ***Visualiser l'image correspondant à l'edge***

# %%
edge_exp.begin.show_source_image(0,0)
edge_exp.end.show_source_image(0,0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ***Visualiser tout le réseau avec l'edge idniqué dessus***

# %%
plot_raw_plus(exp,0,[edge_exp.begin.label,edge_exp.end.label])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
